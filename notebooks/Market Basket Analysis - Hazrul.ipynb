# %% [markdown]
# # Market Basket Analysis
#
# LSESU Data Science Society Project

# %%
#libaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skewnorm 
import sqlite3

# %%
#import data from csv file
df_csv1 = pd.read_csv("online_retail.csv", encoding="unicode_escape") 
df_csv2 = pd.read_csv("online_retail_II.csv",  encoding="unicode_escape")
df_csv1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  Price  Customer ID         Country
# 0  01/12/2010 08:26   2.55      17850.0  United Kingdom
# 1  01/12/2010 08:26   3.39      17850.0  United Kingdom
# 2  01/12/2010 08:26   2.75      17850.0  United Kingdom
# 3  01/12/2010 08:26   3.39      17850.0  United Kingdom
# 4  01/12/2010 08:26   3.39      17850.0  United Kingdom

# %% [markdown]
# ## Cleaning the Data

# %%
print(df_csv1.shape)
print(df_csv2.shape)
# Out:
# (541910, 8)
# (525461, 8)

# %%
df_csv = pd.concat([df_csv1, df_csv2], axis=0)

# %%
df_csv.columns = df_csv.columns.str.lower().str.strip()
df_csv.columns
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'price', 'customer id', 'country'],
#       dtype='object')

# %%
df_csv.isnull().sum() #check null values
# Out:
# invoice             0
# stockcode           0
# description      4382
# quantity            0
# invoicedate         0
# price               0
# customer id    243007
# country             0
# dtype: int64

# %%
df_csv.shape
# Out:
# (1067371, 8)

# %% [markdown]
# total rows 1067371

# %%
df_csv.dtypes #check columns type
# Out:
# invoice         object
# stockcode       object
# description     object
# quantity         int64
# invoicedate     object
# price          float64
# customer id    float64
# country         object
# dtype: object

# %%
df_csv["invoicedate"] = pd.to_datetime(df_csv["invoicedate"], format="%d/%m/%Y %H:%M")
df_csv.dtypes
# Out:
# invoice                object
# stockcode              object
# description            object
# quantity                int64
# invoicedate    datetime64[ns]
# price                 float64
# customer id           float64
# country                object
# dtype: object

# %%
df_csv = df_csv[df_csv["description"].notna()]
df_csv = df_csv[df_csv["quantity"] > 0]
df_csv = df_csv[df_csv["price"]> 0]
df_csv = df_csv[df_csv["country"] == "United Kingdom"]
df_csv.describe()
# Out:
#             quantity          price    customer id
# count  958502.000000  958502.000000  725250.000000
# mean        9.789489       4.021459   15559.119094
# std       122.667472      51.057409    1593.844795
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   14209.000000
# 50%         3.000000       2.100000   15555.000000
# 75%        10.000000       4.150000   16938.000000
# max     80995.000000   25111.090000   18287.000000

# %% [markdown]
# 1. Exclude price below 0
# 2. Exclude quantity below 0
# 3. Exclude NULL descriptions
# 4. Include only UK transactions

# %%
df_csv["description"] = df_csv["description"].str.strip()
df_csv["invoice"] = df_csv["invoice"].astype("str")
df_csv["stockcode"] = df_csv["stockcode"].astype("str")
df_csv.head()
# Out:
#   invoice stockcode                          description  quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  price  customer id         country
# 0 2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00   3.39      17850.0  United Kingdom

# %%
len(df_csv["description"].unique())
# Out:
# 5327

# %%
df_csv[df_csv["description"].str.contains("METAL LANTERN")]
# Out:
#        invoice stockcode          description  quantity         invoicedate  \
# 1       536365     71053  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 50      536373     71053  WHITE METAL LANTERN         6 2010-12-01 09:02:00
# 67      536375     71053  WHITE METAL LANTERN         6 2010-12-01 09:32:00
# 281     536396     71053  WHITE METAL LANTERN         6 2010-12-01 10:51:00
# 417     536406     71053  WHITE METAL LANTERN         8 2010-12-01 11:33:00
# ...        ...       ...                  ...       ...                 ...
# 520021  537678     71053  WHITE METAL LANTERN        24 2010-12-08 09:56:00
# 520360  537759     71053  WHITE METAL LANTERN         4 2010-12-08 11:42:00
# 521182  537811     71053  WHITE METAL LANTERN        24 2010-12-08 13:30:00
# 523065  538010     71053  WHITE METAL LANTERN         4 2010-12-09 12:20:00
# 523128  538012     71053  WHITE METAL LANTERN         3 2010-12-09 12:32:00
#
#         price  customer id         country
# 1        3.39      17850.0  United Kingdom
# 50       3.39      17850.0  United Kingdom
# 67       3.39      17850.0  United Kingdom
# 281      3.39      17850.0  United Kingdom
# 417      3.39      17850.0  United Kingdom
# ...       ...          ...             ...
# 520021   3.39      16779.0  United Kingdom
# 520360   3.75      13126.0  United Kingdom
# 521182   3.39      17262.0  United Kingdom
# 523065   3.75      17526.0  United Kingdom
# 523128   3.75      14527.0  United Kingdom
#
# [771 rows x 8 columns]

# %% [markdown]
# Desctiptions might not be consistent across the same product - one evidence is shown above. Hence, Asssociation Rule Analysis made based on stockcode might be more desirable.

# %%
quantity_big = df_csv[df_csv["quantity"] > 10]
quantity_big.boxplot(column = ["quantity"])
# Out:
# <AxesSubplot:>

# %%
bigger= quantity_big[quantity_big["quantity"] > 1000]
bigger
# Out:
#        invoice stockcode                        description  quantity  \
# 4850    536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945    536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 4946    536830     21915              RED  HARMONICA IN BOX      1400
# 16435   537659     22189            CREAM HEART CARD HOLDER      1008
# 16436   537659     22188            BLACK HEART CARD HOLDER      1008
# ...        ...       ...                                ...       ...
# 507883  536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 507884  536830     21915              RED  HARMONICA IN BOX      1400
# 519373  537659     22189            CREAM HEART CARD HOLDER      1008
# 519374  537659     22188            BLACK HEART CARD HOLDER      1008
# 522918  537981     22492             MINI PAINT SET VINTAGE      1394
#
#                invoicedate  price  customer id         country
# 4850   2010-12-02 16:48:00   0.55      15299.0  United Kingdom
# 4945   2010-12-02 17:38:00   0.18      16754.0  United Kingdom
# 4946   2010-12-02 17:38:00   1.06      16754.0  United Kingdom
# 16435  2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# 16436  2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# ...                    ...    ...          ...             ...
# 507883 2010-12-02 17:38:00   0.18      16754.0  United Kingdom
# 507884 2010-12-02 17:38:00   1.06      16754.0  United Kingdom
# 519373 2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# 519374 2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# 522918 2010-12-09 11:35:00   0.55      17857.0  United Kingdom
#
# [225 rows x 8 columns]

# %%
print(quantity_big[quantity_big["invoice"]=="581458"]["description"])
print(quantity_big[quantity_big["invoice"]=="581115"]["description"])
print(len(bigger["invoice"].unique()))
# Out:
# 540070    POPCORN HOLDER
# Name: description, dtype: object
# 533812    METAL SIGN TAKE IT OR LEAVE IT
# Name: description, dtype: object
# 139

# %% [markdown]
# I suspect a transaction with a very high product quantity might come from a B2B business. A normal customer like you and I will not probably buy a product more than _a certain number_. We can do a rigorous statistical analysis to find _this number_ and then filter out those above it. We would be left with invoice of B2C transactions.
#
# Most B2B transactions will only have one item in their shopping cart.

# %% [markdown]
# Just realised that this based on the UCI website, the customers are mostly wholesalers.

# %%
df_csv.boxplot(column = ["price"])
# Out:
# <AxesSubplot:>

# %%
df_csv[df_csv["price"]>2000]
# Out:
#         invoice  stockcode                          description  quantity  \
# 15017    537632  AMAZONFEE                           AMAZON FEE         1
# 173382   551697       POST                              POSTAGE         1
# 268028   560373          M                               Manual         1
# 297438   562946          M                               Manual         1
# 297725   562955        DOT                       DOTCOM POSTAGE         1
# 299982  A563185          B                      Adjust bad debt         1
# 342997   566927          M                               Manual         1
# 374541   569382          M                               Manual         1
# 431348   573585        DOT                       DOTCOM POSTAGE         1
# 493021   578149        DOT                       DOTCOM POSTAGE         1
# 502058   578833        DOT                       DOTCOM POSTAGE         1
# 524892   580610        DOT                       DOTCOM POSTAGE         1
# 525134   580612        DOT                       DOTCOM POSTAGE         1
# 71077    495798     ADJUST  Adjustment by john on 26/01/2010 17         1
# 74356    496115          M                               Manual         1
# 130004   501772          M                               Manual         1
# 135013   502263          M                               Manual         1
# 135015   502265          M                               Manual         1
# 159967   504639          M                               Manual         1
# 160128   504667          M                               Manual         1
# 166320   505150          M                               Manual         1
# 169667   505505          M                               Manual         1
# 241699   512754          M                               Manual         1
# 241728   512759          M                               Manual         1
# 241827   512771          M                               Manual         1
# 320933   520681          M                               Manual         1
# 342147   522796          M                               Manual         1
# 342161   522798          M                               Manual         1
# 358639   524159          M                               Manual         1
# 358670   524162          M                               Manual         1
# 364486   524711          M                               Manual         1
# 364489   524714          M                               Manual         1
# 372834   525399          M                               Manual         1
# 372865   525403          M                               Manual         1
# 374227   525473          M                               Manual         1
# 374247   525475          M                               Manual         1
# 374499   525503          M                               Manual         1
# 389367   526860          M                               Manual         1
# 394037   527258          M                               Manual         1
# 394199   527271          M                               Manual         1
# 394201   527273          M                               Manual         1
# 440698   531411  AMAZONFEE                           AMAZON FEE         1
# 517955   537632  AMAZONFEE                           AMAZON FEE         1
#
#                invoicedate     price  customer id         country
# 15017  2010-12-07 15:08:00  13541.33          NaN  United Kingdom
\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_csv['price'][df_csv['price'] < 3.75].hist()
# Out:
# <AxesSubplot:>

# %%
df_csv['price'][df_csv['price'] > 3.75].hist()
# Out:
# <AxesSubplot:>

# %%
df_csv[df_csv["invoice"] == "562946"]
# Out:
#        invoice stockcode description  quantity         invoicedate   price  \
# 297438  562946         M      Manual         1 2011-08-11 09:38:00  2500.0
#
#         customer id         country
# 297438      15581.0  United Kingdom

# %% [markdown]
# 1. It's ok for the quantity of a product to be high becausse it's a B2B busineess Confirm this with teamates.
# 2. Need to firgure out a clever way to differentiate between actual product transactions and non product transactions.
# 3. Might need to think about segmenting the customers (business and actual customer)

# %%
non_product = ['m','gift_0001_50','gift_0001_40','gift_0001_30','gift_0001_20','gift_0001_10',"DOT", "M", "B", "POST", "AMAZONFEE", "BANK CHARGES", 'gift_0001_80',
 'gift_0001_70','TEST002','TEST001','D','C2','ADJUST2','ADJUST',  'S']

for product in non_product:
    df_csv = df_csv[df_csv["stockcode"] !=  product]

# %% [markdown]
# 1. m: manual
# 2. gift: voucher
# 3. POST & DOT: delivery
# 4. B: debt
# 5. D: discount
# 6. ADJUST: Accounting adjustments
# 7. C2: carriage

# %%
print(len(df_csv["stockcode"].unique()))
sorted(list(df_csv["stockcode"].unique()), reverse=True)
# Out:
# 4885
# ['SP1002',
#  'PADS',
#  'DCGSSGIRL',
#  'DCGSSBOY',
#  'DCGS0076',
#  'DCGS0075',
#  'DCGS0072',
#  'DCGS0070',
#  'DCGS0069',
#  'DCGS0068',
#  'DCGS0066N',
#  'DCGS0062',
#  'DCGS0058',
#  'DCGS0044',
#  'DCGS0041',
#  'DCGS0037',
#  'DCGS0004',
#  'DCGS0003',
#  '90214Z',
#  '90214Y',
#  '90214W',
#  '90214V',
#  '90214U',
#  '90214T',
#  '90214S',
#  '90214R',
#  '90214P',
#  '90214O',
#  '90214N',
#  '90214M',
#  '90214L',
#  '90214K',
#  '90214J',
#  '90214I',
#  '90214H',
#  '90214G',
#  '90214F',
#  '90214E',
#  '90214D',
#  '90214C',
#  '90214B',
#  '90214A',
#  '90212C',
#  '90212B',
#  '90211B',
#  '90211A',
#  '90210D',
#  '90210C',
#  '90210B',
#  '90210A',
#  '90209C',
#  '90209B',
#  '90209A',
#  '90208',
#  '90206C',
#  '90206A',
#  '90205C',
#  '90205A',
#  '90204',
#  '90203',
#  '90202D',
#  '90202C',
#  '90202B',
#  '90202A',
#  '90201D',
#  '90201C',
#  '90201B',
#  '90201A',
#  '90200E',
#  '90200D',
#  '90200C',
#  '90200B',
#  '90200A',
#  '90199D',
#  '90199C',
#  '90199B',
#  '90199A',
#  '90198B',
#  '90198A',
#  '90197D',
#  '90197B',
#  '90196B',
#  '90196A',
#  '90195B',
#  '90195A',
#  '90194',
#  '90192',
#  '90191',
#  '90190C',
#  '90190B',
#  '90190A',
#  '90189B',
#  '90189A',
#  '90188',
#  '90187B',
#  '90187A',
#  '90186B',
#  '90186A',
#  '90185D',
#  '90185C',
#  '90185B',
#  '90185A',
#  '90184c',
#  '90184C',
#  '90184B',
#  '90184A',
#  '90183c',
#  '90183C',
#  '90183B',
#
#                invoicedate  price  customer id         country
# 3036   2010-12-01 17:06:00   5.94          NaN  United Kingdom
# 13921  2010-12-06 16:57:00   5.94          NaN  United Kingdom
# 37060  2010-12-17 17:08:00   5.94          NaN  United Kingdom
# 313888 2011-08-25 15:50:00   5.95      15663.0  United Kingdom
# 436445 2011-11-03 11:29:00   5.95      13709.0  United Kingdom
# 494977 2011-11-23 14:05:00   5.95      12748.0  United Kingdom
# 496547 2011-11-24 09:21:00   5.82          NaN  United Kingdom
# 529477 2011-12-05 17:28:00   5.82          NaN  United Kingdom
# 30574  2009-12-14 17:16:00   6.07          NaN  United Kingdom
# 41259  2009-12-18 17:15:00   6.07          NaN  United Kingdom
# 42657  2009-12-22 09:41:00   6.07          NaN  United Kingdom
# 50311  2010-01-11 09:34:00   6.07          NaN  United Kingdom
# 60081  2010-01-18 13:15:00   5.94          NaN  United Kingdom
# 72690  2010-01-27 17:53:00   5.94          NaN  United Kingdom
# 132908 2010-03-22 13:11:00   5.94          NaN  United Kingdom
# 133393 2010-03-22 14:34:00   5.95      17138.0  United Kingdom
# 152350 2010-04-08 11:36:00   5.94          NaN  United Kingdom
# 216252 2010-05-28 17:25:00   5.94          NaN  United Kingdom
# 342973 2010-09-17 11:33:00   5.94          NaN  United Kingdom
# 361552 2010-09-28 17:18:00   5.94          NaN  United Kingdom
# 505974 2010-12-01 17:06:00   5.94          NaN  United Kingdom
# 516859 2010-12-06 16:57:00   5.94          NaN  United Kingdom

# %%
df_csv.boxplot(column = ["price"])
# Out:
# <AxesSubplot:>

# %%
df_csv[df_csv["price"]>200]
# Out:
#        invoice stockcode                     description  quantity  \
# 4989    536835     22655     VINTAGE RED KITCHEN CABINET         1
# 32484   539080     22655     VINTAGE RED KITCHEN CABINET         1
# 51636   540647     22655     VINTAGE RED KITCHEN CABINET         1
# 82768   543253     22655     VINTAGE RED KITCHEN CABINET         1
# 118748  546480     22656    VINTAGE BLUE KITCHEN CABINET         1
# 134007  547814     22656    VINTAGE BLUE KITCHEN CABINET         1
# 171178  551393     22656    VINTAGE BLUE KITCHEN CABINET         1
# 205759  554836     22655     VINTAGE RED KITCHEN CABINET         1
# 222671  556444     22502  PICNIC BASKET WICKER 60 PIECES        60
# 222682  556446     22502  PICNIC BASKET WICKER 60 PIECES         1
# 114155  500315     84016      FLAG OF ST GEORGE CAR FLAG         1
# 136403  502451     84016      FLAG OF ST GEORGE CAR FLAG         1
# 180997  506571     84016      FLAG OF ST GEORGE CAR FLAG         1
# 192196  507637     84016      FLAG OF ST GEORGE CAR FLAG         1
# 248762  513439     84016      FLAG OF ST GEORGE CAR FLAG         1
# 268525  515349     22656    VINTAGE BLUE KITCHEN CABINET         1
# 268526  515349     22655     VINTAGE RED KITCHEN CABINET         1
# 268766  515403     22655     VINTAGE RED KITCHEN CABINET         1
# 270553  515602     22656    VINTAGE BLUE KITCHEN CABINET         1
# 272236  515811     22656    VINTAGE BLUE KITCHEN CABINET         1
# 272372  515827     22656    VINTAGE BLUE KITCHEN CABINET         1
# 272372 2010-07-15 10:20:00   295.00      16054.0  United Kingdom
# 275451 2010-07-18 12:19:00   295.00      15151.0  United Kingdom
# 275452 2010-07-18 12:19:00   295.00      15151.0  United Kingdom
# 279619 2010-07-21 14:41:00   295.00      13615.0  United Kingdom
# 282682 2010-07-25 11:07:00   295.00      13875.0  United Kingdom
# 283393 2010-07-25 15:32:00   295.00      16556.0  United Kingdom
# 285383 2010-07-27 08:09:00   295.00      18172.0  United Kingdom
# 287812 2010-07-29 10:00:00   295.00      13340.0  United Kingdom
# 290300 2010-07-30 14:00:00   295.00      13015.0  United Kingdom
# 291647 2010-08-02 11:25:00   295.00      14427.0  United Kingdom
# 292603 2010-08-03 10:26:00   295.00      18260.0  United Kingdom
# 292665 2010-08-03 10:38:00   295.00      15727.0  United Kingdom
# 292666 2010-08-03 10:38:00   295.00      15727.0  United Kingdom
# 301423 2010-08-11 12:59:00   295.00      16985.0  United Kingdom
# 303557 2010-08-12 16:45:00   295.00      18227.0  United Kingdom
# 313339 2010-08-22 12:03:00   295.00      18260.0  United Kingdom
# 316572 2010-08-24 16:08:00   295.00      16985.0  United Kingdom
# 317599 2010-08-25 13:27:00   295.00      16570.0  United Kingdom
# 328960 2010-09-06 13:20:00   295.00      15809.0  United Kingdom
# 355259 2010-09-26 11:23:00   295.00      16833.0  United Kingdom
# 362285 2010-09-29 11:40:00   295.00      15734.0  United Kingdom
# 368233 2010-10-03 12:00:00   295.00      17412.0  United Kingdom
# 368234 2010-10-03 12:00:00   295.00      17412.0  United Kingdom
# 403382 2010-10-20 11:41:00   295.00      15874.0  United Kingdom
# 426333 2010-11-01 13:33:00   295.00      16732.0  United Kingdom
# 466662 2010-11-17 10:31:00   295.00      15874.0  United Kingdom
# 507927 2010-12-02 18:06:00   295.00      13145.0  United Kingdom

# %%
df_csv.describe()
# Out:
#            quantity          price    customer id
# count  955994.00000  955994.000000  724458.000000
# mean        9.80261       3.372446   15559.194692
# std       122.80328       4.809615    1593.732321
# min         1.00000       0.001000   12346.000000
# 25%         1.00000       1.250000   14209.000000
# 50%         3.00000       2.100000   15555.000000
# 75%        10.00000       4.130000   16938.000000
# max     80995.00000    1157.150000   18287.000000

# %%
df_csv = df_csv[df_csv["description"].notna()]
df_csv = df_csv[df_csv["quantity"] > 0]
df_csv = df_csv[df_csv["price"]> 0]
df_csv = df_csv[df_csv["country"] == "United Kingdom"]
df_csv.describe()
# Out:
#            quantity          price    customer id
# count  955994.00000  955994.000000  724458.000000
# mean        9.80261       3.372446   15559.194692
# std       122.80328       4.809615    1593.732321
# min         1.00000       0.001000   12346.000000
# 25%         1.00000       1.250000   14209.000000
# 50%         3.00000       2.100000   15555.000000
# 75%        10.00000       4.130000   16938.000000
# max     80995.00000    1157.150000   18287.000000

# %% [markdown]
# 1. Exclude price below 0
# 2. Exclude quantity below 0
# 3. Exclude NULL descriptions

# %%
df_csv.to_csv("cleaned_data.csv", index=False)

# %%
print(df_csv["invoicedate"].max())
print(df_csv["invoicedate"].min())
# Out:
# 2011-12-09 12:49:00
# 2009-12-01 07:45:00

# %% [markdown]
# ## Using SQL to manipulate the table

# %%
import sqlite3

# make sure of updating the path to a file
conn = sqlite3.connect('retail4.db')
# index = False to ensure the DataFrame row index is not written into the SQL tables
df_csv.to_sql('retail4', con = conn, index = False)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
import sqlite3
import pandas as pd
import seaborn as sns

db = 'retail4.db'

def run_query(q):
    # Connect to the database
    with sqlite3.connect(db) as conn:
        # Wrapper function to read_sql_query(): returns a DataFrame corresponding to the result set of 
        # the query string
        return pd.read_sql(q,conn)

# Function to show all the tables present in the database.
def show_tables():
    q = '''
        SELECT
            name
        FROM sqlite_master
        WHERE type IN ("table","view");
        '''
    return run_query(q)

# Function to count how many rows in each table
def get_table_row_count(tablename):
    q = '''
        SELECT
            COUNT(1)
        FROM %s;
        ''' % tablename
    return run_query(q)["COUNT(1)"][0]

tables = show_tables()
tables["row_count"] = [get_table_row_count(t) for t in tables["name"]]

tables
# Out:
#       name  row_count
# 0  retail4     955994

# %%
df_csv = pd.read_csv("cleaned_data.csv")
df_csv.columns
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'price', 'customer id', 'country'],
#       dtype='object')

# %%
num_items_query = ''' 
SELECT invoice, COUNT(DISTINCT(stockcode)) "num_items", SUM(quantity) "total_quantity", SUM(quantity * price) "total_amount" 
FROM retail4
GROUP BY 1
ORDER BY 4
'''
num_items = run_query(num_items_query)
num_items
# Out:
#        invoice  num_items  total_quantity  total_amount
# 0       528127          1               1          0.19
# 1       570554          1               1          0.38
# 2       502731          1               1          0.42
# 3       507293          1               1          0.42
# 4       518991          1               1          0.42
# ...        ...        ...             ...           ...
# 36179   533027        111           13387      49844.99
# 36180   576365         99           13956      50653.91
# 36181   574941        101           14149      52940.94
# 36182   541431          1           74215      77183.60
# 36183   581483          1           80995     168469.60
#
# [36184 rows x 4 columns]

# %%
num_items.describe()["total_amount"]
# Out:
# count     36184.000000
# mean        476.285134
# std        1444.050310
# min           0.190000
# 25%         148.400000
# 50%         300.130000
# 75%         471.840000
# max      168469.600000
# Name: total_amount, dtype: float64

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    df_low = df_in[(df_in[col_name] < fence_low)]
    df_high = df_in[df_in[col_name] > fence_high]
    return df_out, df_low, df_high

#remove outliers in total _amount
wo_outliers, low_outliers, high_outliers = remove_outlier(potential_cust, "total_amount")
print(wo_outliers.shape)
print(low_outliers.shape)
print(high_outliers.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HAZRUL~1\AppData\Local\Temp/ipykernel_19336/422254717.py in <module>
#      11
#      12 #remove outliers in total _amount
# ---> 13 wo_outliers, low_outliers, high_outliers = remove_outlier(potential_cust, "total_amount")
#      14 print(wo_outliers.shape)
#      15 print(low_outliers.shape)
#
# NameError: name 'potential_cust' is not defined

# %%
#sns.distplot(wo_outliers["total_amount"], kind="hist", kde=True, bins=50, color = 'darkblue')
#print(wo_outliers.describe())

# %%
sns.kdeplot(wo_outliers["total_amount"], shade=True, cumulative=True)

# %%
sns.kdeplot(wo_outliers["total_amount"], shade=True)

# %% [markdown]
# Majority of the customers are purchasing items with a total amount ranging from $100 to $400

# %%
first = wo_outliers["total_amount"].quantile(0.25)
wo_outliers[wo_outliers["total_amount"]<first]
# Out:
#      invoice  num_items  total_quantity  total_amount
# 0     528127          1               1          0.19
# 1     570554          1               1          0.38
# 2     502731          1               1          0.42
# 3     507293          1               1          0.42
# 4     518991          1               1          0.42
# ...      ...        ...             ...           ...
# 8261  565087          7              20        137.38
# 8262  490293         14             130        137.40
# 8263  516260          3              52        137.40
# 8264  523145          4              76        137.40
# 8265  547688          2              52        137.40
#
# [8266 rows x 4 columns]

# %%
#remove outliers in num_items column. removing purchases with extremly high number of different products purchased.
wo_outliers2, low_outliers2, high_outliers2  = remove_outlier(wo_outliers, "num_items")
print(wo_outliers2.shape)
print(low_outliers2.shape)
print(high_outliers2.shape)
# Out:
# (25729, 4)
# (0, 4)
# (1411, 4)

# %%
wo_outliers2.describe()
# Out:
#          num_items  total_quantity  total_amount
# count  25729.00000    25729.000000  25729.000000
# mean      13.70609      126.695635    213.561955
# std       10.85585      123.908526    125.816692
# min        1.00000        1.000000      0.190000
# 25%        5.00000       45.000000    114.060000
# 50%       12.00000       99.000000    205.480000
# 75%       20.00000      176.000000    313.400000
# max       47.00000     3186.000000    471.840000

# %%
#sns.distplot(x="total_amount", y="num_items", data=wo_outliers2)

# %% [markdown]
# Overlapped data points between total-amount and num_items are concentrated in the darker region.

# %%
sns.kdeplot(wo_outliers2["num_items"], shade=True)

# %%
sns.kdeplot(wo_outliers2["total_amount"], shade=True)

# %%
sns.jointplot(x="total_amount", y="num_items",kind="hex", data=wo_outliers2)

# %%
#remove outliers in total_quantity column. removing purchases with extremly high quantity of products purchased.
wo_outliers3, low_outliers3, high_outliers3  = remove_outlier(wo_outliers2, "total_quantity")
print(wo_outliers3.shape)
print(low_outliers3.shape)
print(high_outliers3.shape)
# Out:
# (24857, 4)
# (0, 4)
# (872, 4)

# %%
wo_outliers3.describe()
# Out:
#           num_items  total_quantity  total_amount
# count  29957.000000    29957.000000  29957.000000
# mean      15.718196      142.233368    268.565434
# std       12.646718      112.392305    186.644034
# min        1.000000        1.000000      0.190000
# 25%        5.000000       53.000000    127.200000
# 50%       13.000000      116.000000    242.910000
# 75%       23.000000      208.000000    364.320000
# max       55.000000      483.000000    955.900000

# %% [markdown]
# Removing outliers for each columns so that clustering can work better.
#
# We may agree that an extremly high value for each column indicates that the purchase is made by a wholesler rather than a normal customer.

# %% [markdown]
# ## Clustering

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(wo_outliers3.drop('invoice',axis=1)) 
scaled = pd.DataFrame(scaled,columns = ['num_items','total_quantity', 'total_amount'])
# Out:
#        num_items  total_quantity  total_amount
# 0      -1.163815       -1.256632     -1.437924
# 1      -1.163815       -1.256632     -1.436906
# 2      -1.163815       -1.256632     -1.436692
# 3      -1.163815       -1.256632     -1.436692
# 4      -1.163815       -1.256632     -1.436692
# ...          ...             ...           ...
# 29952   0.654869        2.400263      3.665030
# 29953   0.338576        1.074528      3.665244
# 29954   3.027065        2.969707      3.669799
# 29955   1.920040        2.346878      3.680514
# 29956   2.710773        2.658292      3.682657
#
# [29957 rows x 3 columns]

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
scores = []
silhouette = {}
for i in range(2,10):
    kmeans = KMeans(n_clusters = i, max_iter = 40).fit(scaled)
    cluster_labels = kmeans.labels_
    silhouette[i] = silhouette_score(scaled,cluster_labels)
    scores.append(kmeans.inertia_)

# %%
plt.plot(range(2,10,1), scores)

# %%
silhouette
# Out:
# {2: 0.4117730521896487,
#  3: 0.3504960942179614,
#  4: 0.38766084389273464,
#  5: 0.32852057831931547,
#  6: 0.3341022890145545,
#  7: 0.3480658647964087,
#  8: 0.33666228765720685,
#  9: 0.31642910182280765}

# %%
# Final Model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = 2).fit(scaled)
cluster_labels = kmeans.labels_
wo_outliers3['Cluster'] = cluster_labels
# Out:
# C:\Users\afree\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
wo_outliers3.head()
# Out:
#   invoice  num_items  total_quantity  total_amount  Cluster
# 0  528127          1               1          0.19        0
# 1  570554          1               1          0.38        0
# 2  502731          1               1          0.42        0
# 3  507293          1               1          0.42        0
# 4  518991          1               1          0.42        0

# %%
cluster1 = wo_outliers3[wo_outliers3['Cluster']==0] 
cluster1
# Out:
#       invoice  num_items  total_quantity  total_amount  Cluster
# 0      528127          1               1          0.19        0
# 1      570554          1               1          0.38        0
# 2      502731          1               1          0.42        0
# 3      507293          1               1          0.42        0
# 4      518991          1               1          0.42        0
# ...       ...        ...             ...           ...      ...
# 29652  565469          1              54        591.30        0
# 29754  550754          2              60        597.00        0
# 30010  493409          1              48        612.00        0
# 30016  532643          1              72        612.00        0
# 30566  556446          1               1        649.50        0
#
# [17316 rows x 5 columns]

# %%
cluster2 =wo_outliers3[wo_outliers3['Cluster']==1] 
cluster2
# Out:
#       invoice  num_items  total_quantity  total_amount  Cluster
# 3528   544320          1             480         57.60        1
# 4056   574470         25             250         71.70        1
# 4684   576054         49              59         87.21        1
# 5168   569714         32             253         97.97        1
# 5682   559902         46              97        105.78        1
# ...       ...        ...             ...           ...      ...
# 33048  490067         24             412        952.61        1
# 33049  556072         20             263        952.65        1
# 33051  494395         54             476        953.50        1
# 33060  500118         40             406        955.50        1
# 33062  524524         50             441        955.90        1
#
# [12641 rows x 5 columns]

# %%
sns.kdeplot(x="total_amount", shade=True, hue="Cluster", data=wo_outliers3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-c817a470458c> in <module>
# ----> 1 sns.kdeplot(x="total_amount", shade=True, hue="Cluster", data=wo_outliers3)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     699         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     700                                 kernel, bw, gridsize, cut, clip, legend,
# --> 701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# TypeError: _bivariate_kdeplot() got multiple values for argument 'x'

# %%
sns.kdeplot(x="total_quantity", shade=True, hue="Cluster", data=wo_outliers3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-036697b36a76> in <module>
# ----> 1 sns.kdeplot(x="total_quantity", shade=True, hue="Cluster", data=wo_outliers3)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     699         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     700                                 kernel, bw, gridsize, cut, clip, legend,
# --> 701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# TypeError: _bivariate_kdeplot() got multiple values for argument 'x'

# %%
sns.kdeplot(x="num_items", shade=True, hue="Cluster", data=wo_outliers3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-0323b48c8b88> in <module>
# ----> 1 sns.kdeplot(x="num_items", shade=True, hue="Cluster", data=wo_outliers3)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     699         ax = _bivariate_kdeplot(x, y, shade, shade_lowest,
#     700                                 kernel, bw, gridsize, cut, clip, legend,
# --> 701                                 cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     702     else:
#     703         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#
# TypeError: _bivariate_kdeplot() got multiple values for argument 'x'

# %% [markdown]
# Cluster 0 can be viewed as small customers deduced from the distibutions above while cluster 1 can be view as wholeselers.
#
# The reasons being:
# 1. Cluster 0 is positive skewed for all three distributions. Due to this fact, the mean of this cluster is less than its counterpart for all distributions
# 2. Cluster 1 distributions almost fit a normal distribution for all three features and have higher mean.
#
# Hence, we can conlcude that for each transaction, the majority of cluster 0 prefer to purchase fewer number of different products, fewer quantity and spend less in one basket. The opposite is true for cluster 1.
#
# The joint plots below showcase better insights and reinforce the arguments of the proposition that cluster 0 is a small customers while cluster 1 is a wholeseler.

# %%
sns.jointplot(x="total_amount", y="num_items", kind="hist", hue="Cluster", data=wo_outliers3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-c2b370691764> in <module>
# ----> 1 sns.jointplot(x="total_amount", y="num_items", kind="hist", hue="Cluster", data=wo_outliers3)
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2351     else:
#    2352         msg = "kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'"
# -> 2353         raise ValueError(msg)
#    2354
#    2355     if stat_func is not None:
#
# ValueError: kind must be either 'scatter', 'reg', 'resid', 'kde', or 'hex'

# %%
sns.jointplot(x="total_amount", y="num_items", kind="scatter", hue="Cluster", data=wo_outliers3)

# %%
sns.jointplot(x="total_quantity", y="num_items", kind="hist", hue="Cluster", data=wo_outliers3)

# %%
print(sns.__version__)

# %%
conn.close()
