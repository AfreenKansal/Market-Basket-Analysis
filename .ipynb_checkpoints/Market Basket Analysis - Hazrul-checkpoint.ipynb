# %% [markdown]
# # Market Basket Analysis
#
# LSESU Data Science Society Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


df_csv = pd.read_csv("online_retail.csv", encoding="unicode_escape") #import data from csv file
df_csv.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  Price  Customer ID         Country
# 0  01/12/2010 08:26   2.55      17850.0  United Kingdom
# 1  01/12/2010 08:26   3.39      17850.0  United Kingdom
# 2  01/12/2010 08:26   2.75      17850.0  United Kingdom
# 3  01/12/2010 08:26   3.39      17850.0  United Kingdom
# 4  01/12/2010 08:26   3.39      17850.0  United Kingdom

# %% [markdown]
# ## Cleaning the Data

# %%
df_csv.columns = df_csv.columns.str.lower().str.strip()
df_csv.columns
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'price', 'customer id', 'country'],
#       dtype='object')

# %%
df_csv.isnull().sum() #check null values
# Out:
# invoice             0
# stockcode           0
# description      1454
# quantity            0
# invoicedate         0
# price               0
# customer id    135080
# country             0
# dtype: int64

# %%
df_csv.shape
# Out:
# (541910, 8)

# %% [markdown]
# total rows 541910

# %%
df_csv.dtypes #check columns type
# Out:
# invoice         object
# stockcode       object
# description     object
# quantity         int64
# invoicedate     object
# price          float64
# customer id    float64
# country         object
# dtype: object

# %%
df_csv["invoicedate"] = pd.to_datetime(df_csv["invoicedate"], format="%d/%m/%Y %H:%M")
df_csv.dtypes
# Out:
# invoice                object
# stockcode              object
# description            object
# quantity                int64
# invoicedate    datetime64[ns]
# price                 float64
# customer id           float64
# country                object
# dtype: object

# %%
df_csv = df_csv[df_csv["description"].notna()]
df_csv = df_csv[df_csv["quantity"] > 0]
df_csv = df_csv[df_csv["price"]> 0]
df_csv = df_csv[df_csv["country"] == "United Kingdom"]
df_csv.describe()
# Out:
#             quantity          price    customer id
# count  485123.000000  485123.000000  354321.000000
# mean        9.610738       3.849679   15552.486392
# std       161.904143      34.677371    1594.527150
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   14194.000000
# 50%         3.000000       2.100000   15522.000000
# 75%        10.000000       4.130000   16931.000000
# max     80995.000000   13541.330000   18287.000000

# %% [markdown]
# 1. Exclude price below 0
# 2. Exclude quantity below 0
# 3. Exclude NULL descriptions

# %%
df_csv["description"] = df_csv["description"].str.strip()
df_csv["invoice"] = df_csv["invoice"].astype("str")
df_csv["stockcode"] = df_csv["stockcode"].astype("str")
df_csv.head()
# Out:
#   invoice stockcode                          description  quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  price  customer id         country
# 0 2010-12-01 08:26:00   2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00   2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00   3.39      17850.0  United Kingdom

# %%
len(df_csv["description"].unique())
# Out:
# 3996

# %%
df_csv[df_csv["description"].str.contains("METAL LANTERN")]
# Out:
#        invoice stockcode                   description  quantity  \
# 1       536365     71053           WHITE METAL LANTERN         6
# 50      536373     71053           WHITE METAL LANTERN         6
# 67      536375     71053           WHITE METAL LANTERN         6
# 281     536396     71053           WHITE METAL LANTERN         6
# 417     536406     71053           WHITE METAL LANTERN         8
# ...        ...       ...                           ...       ...
# 534552  581149     71053  WHITE MOROCCAN METAL LANTERN         1
# 534553  581149     71053  WHITE MOROCCAN METAL LANTERN         1
# 536736  581219     71053  WHITE MOROCCAN METAL LANTERN         1
# 539298  581439     71053  WHITE MOROCCAN METAL LANTERN         1
# 541511  581498     71053  WHITE MOROCCAN METAL LANTERN         1
#
#                invoicedate  price  customer id         country
# 1      2010-12-01 08:26:00   3.39      17850.0  United Kingdom
# 50     2010-12-01 09:02:00   3.39      17850.0  United Kingdom
# 67     2010-12-01 09:32:00   3.39      17850.0  United Kingdom
# 281    2010-12-01 10:51:00   3.39      17850.0  United Kingdom
# 417    2010-12-01 11:33:00   3.39      17850.0  United Kingdom
# ...                    ...    ...          ...             ...
# 534552 2011-12-07 14:12:00   3.75      15471.0  United Kingdom
# 534553 2011-12-07 14:12:00   3.75      15471.0  United Kingdom
# 536736 2011-12-08 09:28:00   8.29          NaN  United Kingdom
# 539298 2011-12-08 16:30:00   8.29          NaN  United Kingdom
# 541511 2011-12-09 10:26:00   8.29          NaN  United Kingdom
#
# [334 rows x 8 columns]

# %% [markdown]
# Desctiptions might not be consistent across the same product - one evidence is shown above. Hence, Asssociation Rule Analysis made based on stockcode might be more desirable.

# %%
quantity_big = df_csv[df_csv["quantity"] > 10]
quantity_big.boxplot(column = ["quantity"])
# Out:
# <AxesSubplot:>

# %%
bigger= quantity_big[quantity_big["quantity"] > 1000]
bigger
# Out:
#        invoice stockcode                        description  quantity  \
# 4850    536809     84950     ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945    536830     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 4946    536830     21915              RED  HARMONICA IN BOX      1400
# 16435   537659     22189            CREAM HEART CARD HOLDER      1008
# 16436   537659     22188            BLACK HEART CARD HOLDER      1008
# ...        ...       ...                                ...       ...
# 521375  580363     23582        VINTAGE DOILY JUMBO BAG RED      1500
# 533812  581115     22413     METAL SIGN TAKE IT OR LEAVE IT      1404
# 540070  581458     22197                     POPCORN HOLDER      1500
# 540071  581459     22197                     POPCORN HOLDER      1200
# 540421  581483     23843        PAPER CRAFT , LITTLE BIRDIE     80995
#
#                invoicedate  price  customer id         country
# 4850   2010-12-02 16:48:00   0.55      15299.0  United Kingdom
# 4945   2010-12-02 17:38:00   0.18      16754.0  United Kingdom
# 4946   2010-12-02 17:38:00   1.06      16754.0  United Kingdom
# 16435  2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# 16436  2010-12-07 16:43:00   2.31      18102.0  United Kingdom
# ...                    ...    ...          ...             ...
# 521375 2011-12-02 16:32:00   1.79      13868.0  United Kingdom
# 533812 2011-12-07 12:20:00   2.75      15195.0  United Kingdom
# 540070 2011-12-08 18:45:00   0.72      17949.0  United Kingdom
# 540071 2011-12-08 18:46:00   0.72      17949.0  United Kingdom
# 540421 2011-12-09 09:15:00   2.08      16446.0  United Kingdom
#
# [98 rows x 8 columns]

# %%
print(quantity_big[quantity_big["invoice"]=="581458"]["description"])
print(quantity_big[quantity_big["invoice"]=="581115"]["description"])
print(len(bigger["invoice"].unique()))
# Out:
# 540070    POPCORN HOLDER
# Name: description, dtype: object
# 533812    METAL SIGN TAKE IT OR LEAVE IT
# Name: description, dtype: object
# 75

# %% [markdown]
# I suspect a transaction with a very high product quantity might come from a B2B business. A normal customer like you and I will not probably buy a product more than _a certain number_. We can do a rigorous statistical analysis to find _this number_ and then filter out those above it. We would be left with invoice of B2C transactions.
#
# Most B2B transactions will only have one item in their shopping cart.

# %% [markdown]
# Just realised that this based on the UCI website, the customers are mostly wholesalers.

# %%
df_csv.boxplot(column = ["price"])
# Out:
# <AxesSubplot:>

# %%
df_csv[df_csv["price"]>2000]
# Out:
#         invoice  stockcode      description  quantity         invoicedate  \
# 15017    537632  AMAZONFEE       AMAZON FEE         1 2010-12-07 15:08:00
# 173382   551697       POST          POSTAGE         1 2011-05-03 13:46:00
# 268028   560373          M           Manual         1 2011-07-18 12:30:00
# 297438   562946          M           Manual         1 2011-08-11 09:38:00
# 297725   562955        DOT   DOTCOM POSTAGE         1 2011-08-11 10:14:00
# 299982  A563185          B  Adjust bad debt         1 2011-08-12 14:50:00
# 342997   566927          M           Manual         1 2011-09-15 15:20:00
# 374541   569382          M           Manual         1 2011-10-03 16:44:00
# 431348   573585        DOT   DOTCOM POSTAGE         1 2011-10-31 14:41:00
# 493021   578149        DOT   DOTCOM POSTAGE         1 2011-11-23 11:11:00
# 502058   578833        DOT   DOTCOM POSTAGE         1 2011-11-25 15:23:00
# 524892   580610        DOT   DOTCOM POSTAGE         1 2011-12-05 11:48:00
# 525134   580612        DOT   DOTCOM POSTAGE         1 2011-12-05 11:58:00
#
#            price  customer id         country
# 15017   13541.33          NaN  United Kingdom
# 173382   8142.75      16029.0  United Kingdom
# 268028   4287.63          NaN  United Kingdom
# 297438   2500.00      15581.0  United Kingdom
# 297725   4505.17          NaN  United Kingdom
# 299982  11062.06          NaN  United Kingdom
# 342997   2033.10      17846.0  United Kingdom
# 374541   3155.95      15502.0  United Kingdom
# 431348   2019.05          NaN  United Kingdom
# 493021   2275.54          NaN  United Kingdom
# 502058   2028.25          NaN  United Kingdom
# 524892   2196.67          NaN  United Kingdom
# 525134   2114.00          NaN  United Kingdom

# %% [markdown]
# the file does include some weird transactions. some are displayed above.So not all stockcode represent products as shown above.

# %%
df_csv[df_csv["invoice"] == "562946"]
# Out:
#        invoice stockcode description  quantity         invoicedate   price  \
# 297438  562946         M      Manual         1 2011-08-11 09:38:00  2500.0
#
#         customer id         country
# 297438      15581.0  United Kingdom

# %% [markdown]
# 1. It's ok for the quantity of a product to be high becausse it's a B2B busineess Confirm this with teamates.
# 2. Need to firgure out a clever way to differentiate between actual product transactions and non product transactions.
# 3. Might need to think about segmenting the customers (business and actual customer)

# %%
non_product = ['m','gift_0001_50','gift_0001_40','gift_0001_30','gift_0001_20','gift_0001_10',"DOT", "M", "B", "POST", "AMAZONFEE", "BANK CHARGES"]

for product in non_product:
    df_csv = df_csv[df_csv["stockcode"] !=  product]

# %% [markdown]
# 1. m: manual
#  '85230B',
#  '85230A',
#  '85227',
#  '85225',
#  '85224',
#  '85216',
#  '85215',
#  '85214',
#  '85213',
#  '85212',
#  '85211',
#  '85208',
#  '85206B',
#  '85206A',
#  '85205B',
#  '85204',
#  '85203',
#  '85202',
#  '85200',
#  '85199S',
#  '85199L',
#  '85198',
#  '85197',
#  '85195',
#  '85194S',
#  '85194L',
#  '85189',
#  '85188B',
#  '85188A',
#  '85187',
#  '85186C',
#  '85186A',
#  '85185D',
#  '85185B',
#  '85184c',
#  '85184C',
#  '85183B',
#  '85183A',
#  '85180B',
#  '85180A',
#  '85179a',
#  '85179C',
#  '85179A',
#  '85178',
#  '85177',
#  '85176',
#  '85175',
#  '85174',
#  '85173',
#  '85172',
#  '85170D',
#  '85170C',
#  '85170B',
#  '85170A',
#  '85169D',
#  '85169C',
#  '85169B',
#  '85169A',
#  '85168B',
#  '85167B',
#  '85163B',
#  '85163A',
#  '85161',
#  '85160a',
#  '85160B',
#  '85160A',
#  '85159B',
#  '85159A',
#  '85152',
#  '85150',
#  '85146',
#  '85145',
#  '85144',
#  '85141',
#  '85136C',
#  '85136B',
#  '85136A',
#  '85135C',
#  '85135B',
#  '85135A',
#  '85132c',
#  '85132b',
#  '85132a',
#  '85132C',
#  '85132B',
#  '85132A',
#  '85131D',
#  '85131C',
#  '85131B',
#  '85131A',
#  '85130D',
#  '85130C',
#  '85130B',
#  '85130A',
#  '85129D',
#  '85129C',
#  '85129B',
#  '85127',
#  '85126',
#  '85125',
#  '85124C',
#  '85124B',
#  '85123a',
#  '85123A',
#  '85119',
#  '85118',
#  '85116',
#  '85115B',
#  '85114c',
#  '85114b',
#  '85114a',
#  '85114C',
#  '85114B',
#  '85114A',
#  '85111',
#  '85109',
#  '85107',
#  '85106',
#  '85104',
#  '85103',
#  '85099f',
#  '85099F',
#  '85099C',
#  '85099B',
#  '85096',
#  '85095',
#  '85094',
#  '85093',
#  '85092',
#  '85089',
#  '85088',
#  '85087',
#  '85086A',
#  '85084',
#  '85078',
#  '85071D',
#  '85071C',
#  '85071B',
#  '85071A',
#  '85067',
#  '85066',
#  '85064',
#  '85062',
#  '85061W',
#  '85059',
#  '85055',
#  '85054',
#  '85053',
#  '85049g',
#  '85049e',
#  '85049d',
#  '85049c',
#  '85049b',
#  '85049a',
#  '85049H',
#  '85049G',
#  '85049F',
#  '85049E',
#  '85049D',
#  '85049C',
#  '85049B',
#  '85049A',
#  '85048',
#  '85047',
#  '85045',
#  '85040a',
#  '85040B',
#  '85040A',
#  '85039a',
#  '85039C',
#  '85039B',
#  '85039A',
#  '85038',
#  '85036b',
#  '85036a',
#  '85036C',
#  '85036B',
#  '85036A',
#  '85035c',
#  '85035b',
#  '85035a',
#  '85035C',
#  '85035B',
#  '85035A',
#  '85034b',
#  '85034a',
#  '85034C',
#  '85034B',
#  '85034A',
#  '85032D',
#  '85032C',
#  '85032B',
#  '85032A',
#  '85031C',
#  '85031B',
#  '85031A',
#  '85030',
#  '85028S',
#  '85028L',
#  '85027L',
#  '85026B',
#  '85025C',
#  '85025B',
#  '85024C',
#  '85024B',
#  '85023B',
#  '85020',
# Out:
# <AxesSubplot:>

# %%
df_csv.describe()
# Out:
#             quantity          price    customer id
# count  484039.000000  484039.000000  354018.000000
# mean        9.615733       3.295911   15552.425442
# std       162.049221       4.443089    1594.475423
# min         1.000000       0.001000   12346.000000
# 25%         1.000000       1.250000   14194.000000
# 50%         3.000000       2.100000   15522.000000
# 75%        10.000000       4.130000   16931.000000
# max     80995.000000     649.500000   18287.000000

# %%
df_csv.to_csv("cleaned_data.csv", index=False)

# %%
print(df_csv["invoicedate"].max())
print(df_csv["invoicedate"].min())
# Out:
# 2011-12-09 12:50:00
# 2010-12-01 08:26:00

# %% [markdown]
# ## Using SQL to manipulate the table

# %%
import sqlite3

# make sure of updating the path to a file
conn = sqlite3.connect('retail4.db')

# index = False to ensure the DataFrame row index is not written into the SQL tables
df_csv.to_sql('retail4', con = conn, index = False)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\generic.py:2605: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
import sqlite3
import pandas as pd

db = 'retail2.db'

def run_query(q):
    # Connect to the database
    with sqlite3.connect(db) as conn:
        # Wrapper function to read_sql_query(): returns a DataFrame corresponding to the result set of 
        # the query string
        return pd.read_sql(q,conn)
 
# Function to show all the tables present in the database.
def show_tables():
    q = '''
        SELECT
            name
        FROM sqlite_master
        WHERE type IN ("table","view");
        '''
    return run_query(q)

# Function to count how many rows in each table
def get_table_row_count(tablename):
    q = '''
        SELECT
            COUNT(1)
        FROM %s;
        ''' % tablename
    return run_query(q)["COUNT(1)"][0]

tables = show_tables()
tables["row_count"] = [get_table_row_count(t) for t in tables["name"]]

tables
# Out:
#       name  row_count
# 0  retail2     530692

# %%
df_csv.columns
# Out:
# Index(['invoice', 'stockcode', 'description', 'quantity', 'invoicedate',
#        'price', 'customer id', 'country'],
#       dtype='object')

# %%
num_items_query = ''' 
SELECT invoice, COUNT(DISTINCT(stockcode)) "num_items", SUM(quantity) "total_quantity"
FROM retail2
GROUP BY 1
ORDER BY 2
'''
num_items = run_query(num_items_query)
num_items
# Out:
#       invoice  num_items  total_quantity
# 0      536369          1               3
# 1      536371          1              80
# 2      536374          1              32
# 3      536380          1              24
# 4      536393          1               8
# ...       ...        ...             ...
# 20129  558475        704            4137
# 20130  580729        721            2456
# 20131  581492        731            2011
# 20132  581219        749            2151
# 20133  573585       1110            5198
#
# [20134 rows x 3 columns]

# %%
num_items["num_items"].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
num_items.describe()
# Out:
#           num_items  total_quantity
# count  20134.000000    20134.000000
# mean      25.834757      279.548674
# std       46.835651      956.222442
# min        1.000000        1.000000
# 25%        6.000000       68.000000
# 50%       15.000000      150.000000
# 75%       29.000000      295.000000
# max     1110.000000    80995.000000

# %%
num_items.boxplot(column = ["total_quantity"])
# Out:
# <AxesSubplot:>

# %%
sns.displot(num_items["num_items"], bins=40)

# %%
below_50 = num_items[num_items["num_items"] <= 50]
sns.displot(below_50["num_items"], bins=40)

# %%
distinct_query = '''
SELECT COUNT(DISTINCT(invoice)) "num_invoices", COUNT(DISTINCT(description)) "num_products"
FROM retail2
'''

run_query(distinct_query)
# Out:
#    num_invoices  num_products
# 0         20134          4077

# %%
conn.close()
